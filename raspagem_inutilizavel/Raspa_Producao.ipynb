# %%
pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (4.13.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from requests) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

# Função que faz o scraping para um ano específico
def raspar_dados_ano(ano):
    url = f"http://vitibrasil.cnpuv.embrapa.br/index.php?opcao=opt_02&ano={ano}"
    resposta = requests.get(url)

    if resposta.status_code == 200:
        soup = BeautifulSoup(resposta.text, 'html.parser')

        # Encontra a tabela (pode ajustar se tiver mais de uma tabela na página)
        tabela = soup.find('table', {'class': 'tb_base tb_dados'})

        if tabela:
            linhas = tabela.find_all('tr')
            dados = []
            categoria_atual = None
            
            for linha in linhas:
                colunas = linha.find_all('td')
                
                if not colunas:
                    continue  # Pula linhas vazias
                
                primeira_coluna = colunas[0]
                
                if 'tb_item' in primeira_coluna.get('class', []):
                    categoria_atual = primeira_coluna.text.strip()
                    dados.append({
                        'Categoria': categoria_atual,
                        'Produto': '-',
                        'Quantidade(L.)': [col.text.strip() for col in colunas[1:]]
                    })
                elif 'tb_subitem' in primeira_coluna.get('class', []):
                    produto = primeira_coluna.text.strip()
                    dados.append({
                        'Categoria': categoria_atual,
                        'Produto': produto,
                        'Quantidade(L.)': [col.text.strip() for col in colunas[1:]]
                    })
            
            # Exibir os dados organizados
            #for d in dados:
                #print(f"{d['Categoria']} -> {d['Produto']} | {d['Quantidade']}")

            return dados
        else:
            print(f"Nenhuma tabela encontrada para o ano {ano}")
            return None
    else:
        print(f"Erro ao acessar o ano {ano}: {resposta.status_code}")
        return None

# Exemplo: pegar dados de 2023
dados = raspar_dados_ano(2023)

# Exibir resultado
for linha in dados:
    print(linha)
# Out:
# {'Categoria': 'VINHO DE MESA', '-': '-', 'Quantidade(L.)': ['169.762.429']}
# {'Categoria': 'VINHO DE MESA', 'Produto': 'Tinto', 'Quantidade(L.)': ['139.320.884']}
# {'Categoria': 'VINHO DE MESA', 'Produto': 'Branco', 'Quantidade(L.)': ['27.910.299']}
# {'Categoria': 'VINHO DE MESA', 'Produto': 'Rosado', 'Quantidade(L.)': ['2.531.246']}
# {'Categoria': 'VINHO FINO DE MESA (VINIFERA)', '-': '-', 'Quantidade(L.)': ['46.268.556']}
# {'Categoria': 'VINHO FINO DE MESA (VINIFERA)', 'Produto': 'Tinto', 'Quantidade(L.)': ['23.615.783']}
# {'Categoria': 'VINHO FINO DE MESA (VINIFERA)', 'Produto': 'Branco', 'Quantidade(L.)': ['20.693.437']}
# {'Categoria': 'VINHO FINO DE MESA (VINIFERA)', 'Produto': 'Rosado', 'Quantidade(L.)': ['1.959.336']}
# {'Categoria': 'SUCO', '-': '-', 'Quantidade(L.)': ['67.045.238']}
# {'Categoria': 'SUCO', 'Produto': 'Suco de uva integral', 'Quantidade(L.)': ['38.122.173']}
# {'Categoria': 'SUCO', 'Produto': 'Suco de uva concentrado', 'Quantidade(L.)': ['28.216.760']}
# {'Categoria': 'SUCO', 'Produto': 'Suco de uva adoçado', 'Quantidade(L.)': ['94.587']}
# {'Categoria': 'SUCO', 'Produto': 'Suco de uva orgânico', 'Quantidade(L.)': ['611.718']}
# {'Categoria': 'SUCO', 'Produto': 'Suco de uva reconstituído', 'Quantidade(L.)': ['-']}
# {'Categoria': 'DERIVADOS', '-': '-', 'Quantidade(L.)': ['174.716.647']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Espumante', 'Quantidade(L.)': ['65.525']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Espumante moscatel', 'Quantidade(L.)': ['14.744']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Base espumante', 'Quantidade(L.)': ['-']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Base espumante moscatel', 'Quantidade(L.)': ['6.734.590']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Base Champenoise champanha', 'Quantidade(L.)': ['1.552.243']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Base Charmat champanha', 'Quantidade(L.)': ['5.418.118']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Bebida de uva', 'Quantidade(L.)': ['1.627']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Polpa de uva', 'Quantidade(L.)': ['1.388.251']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Mosto simples', 'Quantidade(L.)': ['157.848.983']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Mosto concentrado', 'Quantidade(L.)': ['-']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Mosto de uva com bagaço', 'Quantidade(L.)': ['7.784']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Mosto dessulfitado', 'Quantidade(L.)': ['-']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Mistelas', 'Quantidade(L.)': ['600']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Néctar de uva', 'Quantidade(L.)': ['70.976']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Licorosos', 'Quantidade(L.)': ['-']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Compostos', 'Quantidade(L.)': ['-']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Jeropiga', 'Quantidade(L.)': ['4.500']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Filtrado', 'Quantidade(L.)': ['-']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Frisante', 'Quantidade(L.)': ['-']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Vinho leve', 'Quantidade(L.)': ['-']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Vinho licoroso', 'Quantidade(L.)': ['73.600']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Brandy', 'Quantidade(L.)': ['450']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Destilado', 'Quantidade(L.)': ['-']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Bagaceira', 'Quantidade(L.)': ['-']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Licor de bagaceira', 'Quantidade(L.)': ['-']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Vinagre', 'Quantidade(L.)': ['9.000']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Borra líquida', 'Quantidade(L.)': ['758.140']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Borra seca', 'Quantidade(L.)': ['17.200']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Vinho Composto', 'Quantidade(L.)': ['-']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Pisco', 'Quantidade(L.)': ['-']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Vinho orgânico', 'Quantidade(L.)': ['94.150']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Espumante orgânico', 'Quantidade(L.)': ['1.365']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Destilado alcoólico simples de bagaceira', 'Quantidade(L.)': ['-']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Vinho acidificado', 'Quantidade(L.)': ['2.500']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Mosto parcialmente fermentado', 'Quantidade(L.)': ['-']}
# {'Categoria': 'DERIVADOS', 'Produto': 'Outros derivados', 'Quantidade(L.)': ['652.301']}
