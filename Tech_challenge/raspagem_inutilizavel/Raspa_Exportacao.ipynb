# %%
pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (4.13.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from requests) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\alexa\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

# Função que faz o scraping para um ano específico
def raspar_dados_ano(ano, sub):
    url = f"http://vitibrasil.cnpuv.embrapa.br/index.php?ano={ano}&opcao=opt_06&subopcao={sub}"
    resposta = requests.get(url)

    if resposta.status_code == 200:
        soup = BeautifulSoup(resposta.text, 'html.parser')

        # Encontra a tabela (pode ajustar se tiver mais de uma tabela na página)
        tabela = soup.find('table', {'class': 'tb_base tb_dados'})

        if tabela:
            linhas = tabela.find_all('tr')
            dados = []
            categoria_atual = None
            
            for linha in linhas:
                colunas = linha.find_all('td')
                
                if not colunas:
                    continue  # Pula linhas vazias
                
                primeira_coluna = colunas[0]
                segunda_coluna = colunas[1]
                terceira_coluna = colunas[2]

                pais = primeira_coluna.text.strip()
                qtd = segunda_coluna.text.strip()
                vlr = terceira_coluna.text.strip()
                dados.append({
                    'Países': pais,
                    'Quantidade (Kg)': qtd,
                    'Valor (US$)': vlr
                })
            
            # Exibir os dados organizados
            for d in dados:
                print(f"{d['Países']} -> {d['Quantidade (Kg)']} | {d['Valor (US$)']}")

            return dados
        else:
            print(f"Nenhuma tabela encontrada para o ano {ano}")
            return None
    else:
        print(f"Erro ao acessar o ano {ano}: {resposta.status_code}")
        return None

# Exemplo: pegar dados de 2024
dados = raspar_dados_ano(2024,'subopt_01')

# Exibir resultado
for linha in dados:
    print(linha)
# Out:
# Afeganistão -> - | -
# África do Sul -> 103 | 1.783
# Alemanha, República Democrática -> 6.666 | 48.095
# Angola -> - | -
# Anguilla -> - | -
# Antígua e Barbuda -> 447 | 3.329
# Antilhas Holandesas -> - | -
# Arábia Saudita -> 32 | 54
# Argélia -> 6 | 87
# Argentina -> 21.015 | 167.696
# Aruba -> - | -
# Austrália -> 2.070 | 19.152
# Áustria -> - | -
# Bahamas -> 1.632 | 7.457
# Bangladesh -> - | -
# Barbados -> 773 | 580
# Barein -> 178 | 1.044
# Bélgica -> 960 | 8.334
# Belice -> - | -
# Benin -> - | -
# Bermudas -> 102 | 823
# Bolívia -> 20.334 | 30.293
# Bósnia-Herzegovina -> - | -
# Brasil -> 96 | 244
# Bulgária -> 18 | 184
# Cabo Verde -> - | -
# Camarões -> - | -
# Canadá -> 4.320 | 35.179
# Catar -> - | -
# Cayman, Ilhas -> 180 | 591
# Chile -> - | -
# China -> 34.231 | 182.595
# Chipre -> 988 | 4.308
# Cingapura -> - | -
# Cocos (Keeling), Ilhas -> - | -
# Colômbia -> - | -
# Comores -> - | -
# Congo -> 2.340 | 3.753
# Coreia, Republica Sul -> 173 | 1.050
# Costa do Marfim -> - | -
# Costa Rica -> - | -
# Coveite (Kuweit) -> 16 | 72
# Croácia -> 23 | 44
# Cuba -> - | -
# Curaçao -> 25.146 | 50.990
# Dinamarca -> 11 | 185
# Dominica -> 947 | 4.545
# El Salvador -> - | -
# Emirados Arabes Unidos -> 1.688 | 8.253
# Equador -> - | -
# Eslovaca, Republica -> - | -
# Espanha -> 191 | 2.062
# Estados Unidos -> 310.410 | 648.724
# Estônia -> - | -
# Filipinas -> 11.514 | 27.378
# Finlândia -> - | -
# França -> 3.729 | 29.768
# Gabão -> 5 | 18
# Gana -> 54.828 | 91.317
# Gibraltar -> 5 | 13
# Granada -> - | -
# Grécia -> 617 | 2.051
# Guatemala -> 7.957 | 14.268
# Guiana -> 115.884 | 349.244
# Guiana Francesa -> - | -
# Guine Bissau -> - | -
# Guine Equatorial -> 2.250 | 4.279
# Haiti -> 450.690 | 713.158
# Honduras -> - | -
# Hong Kong -> 6.696 | 30.490
# Hungria -> 14 | 27
# Ilha de Man -> 124 | 587
# Ilhas Virgens -> - | -
# Índia -> - | -
# Indonésia -> - | -
# Irã -> - | -
# Iraque -> - | -
# Irlanda -> 32 | 132
# Itália -> 2.431 | 11.642
# Jamaica -> - | -
# Japão -> 29.320 | 66.956
# Jordânia -> - | -
# Letônia -> 33.273 | 144.229
# Líbano -> - | -
# Libéria -> 12.024 | 38.576
# Luxemburgo -> 72 | 832
# Macau -> - | -
# Malásia -> - | -
# Malavi -> - | -
# Malta -> 6.302 | 16.586
# Marshall, Ilhas -> 5.628 | 23.195
# Martinica -> - | -
# Mauritânia -> - | -
# México -> 2.277 | 7.938
# Moçambique -> - | -
# Montenegro -> - | -
# Namíbia -> - | -
# Nicarágua -> - | -
# Nigéria -> 808 | 2.052
# Noruega -> 309 | 2.185
# Nova Caledônia -> - | -
# Nova Zelândia -> - | -
# Omã -> - | -
# Países Baixos -> 3.074 | 22.785
# Palau -> 30 | 320
# Panamá -> 121.432 | 97.549
# Paraguai -> 3.705.268 | 5.121.857
# Peru -> - | -
# Pitcairn -> - | -
# Polônia -> - | -
# Porto Rico -> - | -
# Portugal -> 26.340 | 50.923
# Quênia -> - | -
# Reino Unido -> 14.780 | 106.713
# República Dominicana -> - | -
# Rússia -> 56 | 338
# São Cristóvão e Névis -> - | -
# São Tomé e Príncipe -> - | -
# São Vicente e Granadinas -> - | -
# Senegal -> - | -
# Serra Leoa -> 36.608 | 68.151
# Sérvia -> 10.482 | 25.379
# Singapura -> 4.141 | 20.048
# Suazilândia -> - | -
# Suécia -> - | -
# Suíça -> 2.350 | 23.791
# Suriname -> 27.900 | 71.483
# Tailândia -> 266 | 1.910
# Taiwan (Formosa) -> - | -
# Tanzânia -> 3 | 35
# Tcheca, República -> 2.273 | 20.973
# Togo -> 27.630 | 48.070
# Toquelau -> - | -
# Trinidade Tobago -> 64 | 199
# Tunísia -> - | -
# Turquia -> 216 | 540
# Tuvalu -> - | -
# Uruguai -> 36.729 | 62.325
# Vanuatu -> - | -
# Venezuela -> 122.922 | 199.418
# Vietnã -> 16 | 41
# Total -> 5.324.465 | 8.751.275
# {'Países': 'Afeganistão', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'África do Sul', 'Quantidade (Kg)': '103', 'Valor (US$)': '1.783'}
# {'Países': 'Alemanha, República Democrática', 'Quantidade (Kg)': '6.666', 'Valor (US$)': '48.095'}
# {'Países': 'Angola', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Anguilla', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Antígua e Barbuda', 'Quantidade (Kg)': '447', 'Valor (US$)': '3.329'}
# {'Países': 'Antilhas Holandesas', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Arábia Saudita', 'Quantidade (Kg)': '32', 'Valor (US$)': '54'}
# {'Países': 'Argélia', 'Quantidade (Kg)': '6', 'Valor (US$)': '87'}
# {'Países': 'Argentina', 'Quantidade (Kg)': '21.015', 'Valor (US$)': '167.696'}
# {'Países': 'Aruba', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Austrália', 'Quantidade (Kg)': '2.070', 'Valor (US$)': '19.152'}
# {'Países': 'Áustria', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Bahamas', 'Quantidade (Kg)': '1.632', 'Valor (US$)': '7.457'}
# {'Países': 'Bangladesh', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Barbados', 'Quantidade (Kg)': '773', 'Valor (US$)': '580'}
# {'Países': 'Barein', 'Quantidade (Kg)': '178', 'Valor (US$)': '1.044'}
# {'Países': 'Bélgica', 'Quantidade (Kg)': '960', 'Valor (US$)': '8.334'}
# {'Países': 'Belice', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Benin', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Bermudas', 'Quantidade (Kg)': '102', 'Valor (US$)': '823'}
# {'Países': 'Bolívia', 'Quantidade (Kg)': '20.334', 'Valor (US$)': '30.293'}
# {'Países': 'Bósnia-Herzegovina', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Brasil', 'Quantidade (Kg)': '96', 'Valor (US$)': '244'}
# {'Países': 'Bulgária', 'Quantidade (Kg)': '18', 'Valor (US$)': '184'}
# {'Países': 'Cabo Verde', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Camarões', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Canadá', 'Quantidade (Kg)': '4.320', 'Valor (US$)': '35.179'}
# {'Países': 'Catar', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Cayman, Ilhas', 'Quantidade (Kg)': '180', 'Valor (US$)': '591'}
# {'Países': 'Chile', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'China', 'Quantidade (Kg)': '34.231', 'Valor (US$)': '182.595'}
# {'Países': 'Chipre', 'Quantidade (Kg)': '988', 'Valor (US$)': '4.308'}
# {'Países': 'Cingapura', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Cocos (Keeling), Ilhas', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Colômbia', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Comores', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Congo', 'Quantidade (Kg)': '2.340', 'Valor (US$)': '3.753'}
# {'Países': 'Coreia, Republica Sul', 'Quantidade (Kg)': '173', 'Valor (US$)': '1.050'}
# {'Países': 'Costa do Marfim', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Costa Rica', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Coveite (Kuweit)', 'Quantidade (Kg)': '16', 'Valor (US$)': '72'}
# {'Países': 'Croácia', 'Quantidade (Kg)': '23', 'Valor (US$)': '44'}
# {'Países': 'Cuba', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Curaçao', 'Quantidade (Kg)': '25.146', 'Valor (US$)': '50.990'}
# {'Países': 'Dinamarca', 'Quantidade (Kg)': '11', 'Valor (US$)': '185'}
# {'Países': 'Dominica', 'Quantidade (Kg)': '947', 'Valor (US$)': '4.545'}
# {'Países': 'El Salvador', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Emirados Arabes Unidos', 'Quantidade (Kg)': '1.688', 'Valor (US$)': '8.253'}
# {'Países': 'Equador', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Eslovaca, Republica', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Espanha', 'Quantidade (Kg)': '191', 'Valor (US$)': '2.062'}
# {'Países': 'Estados Unidos', 'Quantidade (Kg)': '310.410', 'Valor (US$)': '648.724'}
# {'Países': 'Estônia', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Filipinas', 'Quantidade (Kg)': '11.514', 'Valor (US$)': '27.378'}
# {'Países': 'Finlândia', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'França', 'Quantidade (Kg)': '3.729', 'Valor (US$)': '29.768'}
# {'Países': 'Gabão', 'Quantidade (Kg)': '5', 'Valor (US$)': '18'}
# {'Países': 'Gana', 'Quantidade (Kg)': '54.828', 'Valor (US$)': '91.317'}
# {'Países': 'Gibraltar', 'Quantidade (Kg)': '5', 'Valor (US$)': '13'}
# {'Países': 'Granada', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Grécia', 'Quantidade (Kg)': '617', 'Valor (US$)': '2.051'}
# {'Países': 'Guatemala', 'Quantidade (Kg)': '7.957', 'Valor (US$)': '14.268'}
# {'Países': 'Guiana', 'Quantidade (Kg)': '115.884', 'Valor (US$)': '349.244'}
# {'Países': 'Guiana Francesa', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Guine Bissau', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Guine Equatorial', 'Quantidade (Kg)': '2.250', 'Valor (US$)': '4.279'}
# {'Países': 'Haiti', 'Quantidade (Kg)': '450.690', 'Valor (US$)': '713.158'}
# {'Países': 'Honduras', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Hong Kong', 'Quantidade (Kg)': '6.696', 'Valor (US$)': '30.490'}
# {'Países': 'Hungria', 'Quantidade (Kg)': '14', 'Valor (US$)': '27'}
# {'Países': 'Ilha de Man', 'Quantidade (Kg)': '124', 'Valor (US$)': '587'}
# {'Países': 'Ilhas Virgens', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Índia', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Indonésia', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Irã', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Iraque', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Irlanda', 'Quantidade (Kg)': '32', 'Valor (US$)': '132'}
# {'Países': 'Itália', 'Quantidade (Kg)': '2.431', 'Valor (US$)': '11.642'}
# {'Países': 'Jamaica', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Japão', 'Quantidade (Kg)': '29.320', 'Valor (US$)': '66.956'}
# {'Países': 'Jordânia', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Letônia', 'Quantidade (Kg)': '33.273', 'Valor (US$)': '144.229'}
# {'Países': 'Líbano', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Libéria', 'Quantidade (Kg)': '12.024', 'Valor (US$)': '38.576'}
# {'Países': 'Luxemburgo', 'Quantidade (Kg)': '72', 'Valor (US$)': '832'}
# {'Países': 'Macau', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Malásia', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Malavi', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Malta', 'Quantidade (Kg)': '6.302', 'Valor (US$)': '16.586'}
# {'Países': 'Marshall, Ilhas', 'Quantidade (Kg)': '5.628', 'Valor (US$)': '23.195'}
# {'Países': 'Martinica', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Mauritânia', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'México', 'Quantidade (Kg)': '2.277', 'Valor (US$)': '7.938'}
# {'Países': 'Moçambique', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Montenegro', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Namíbia', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Nicarágua', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Nigéria', 'Quantidade (Kg)': '808', 'Valor (US$)': '2.052'}
# {'Países': 'Noruega', 'Quantidade (Kg)': '309', 'Valor (US$)': '2.185'}
# {'Países': 'Nova Caledônia', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Nova Zelândia', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Omã', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Países Baixos', 'Quantidade (Kg)': '3.074', 'Valor (US$)': '22.785'}
# {'Países': 'Palau', 'Quantidade (Kg)': '30', 'Valor (US$)': '320'}
# {'Países': 'Panamá', 'Quantidade (Kg)': '121.432', 'Valor (US$)': '97.549'}
# {'Países': 'Paraguai', 'Quantidade (Kg)': '3.705.268', 'Valor (US$)': '5.121.857'}
# {'Países': 'Peru', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Pitcairn', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Polônia', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Porto Rico', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Portugal', 'Quantidade (Kg)': '26.340', 'Valor (US$)': '50.923'}
# {'Países': 'Quênia', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Reino Unido', 'Quantidade (Kg)': '14.780', 'Valor (US$)': '106.713'}
# {'Países': 'República Dominicana', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Rússia', 'Quantidade (Kg)': '56', 'Valor (US$)': '338'}
# {'Países': 'São Cristóvão e Névis', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'São Tomé e Príncipe', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'São Vicente e Granadinas', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Senegal', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Serra Leoa', 'Quantidade (Kg)': '36.608', 'Valor (US$)': '68.151'}
# {'Países': 'Sérvia', 'Quantidade (Kg)': '10.482', 'Valor (US$)': '25.379'}
# {'Países': 'Singapura', 'Quantidade (Kg)': '4.141', 'Valor (US$)': '20.048'}
# {'Países': 'Suazilândia', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Suécia', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Suíça', 'Quantidade (Kg)': '2.350', 'Valor (US$)': '23.791'}
# {'Países': 'Suriname', 'Quantidade (Kg)': '27.900', 'Valor (US$)': '71.483'}
# {'Países': 'Tailândia', 'Quantidade (Kg)': '266', 'Valor (US$)': '1.910'}
# {'Países': 'Taiwan (Formosa)', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Tanzânia', 'Quantidade (Kg)': '3', 'Valor (US$)': '35'}
# {'Países': 'Tcheca, República', 'Quantidade (Kg)': '2.273', 'Valor (US$)': '20.973'}
# {'Países': 'Togo', 'Quantidade (Kg)': '27.630', 'Valor (US$)': '48.070'}
# {'Países': 'Toquelau', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Trinidade Tobago', 'Quantidade (Kg)': '64', 'Valor (US$)': '199'}
# {'Países': 'Tunísia', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Turquia', 'Quantidade (Kg)': '216', 'Valor (US$)': '540'}
# {'Países': 'Tuvalu', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Uruguai', 'Quantidade (Kg)': '36.729', 'Valor (US$)': '62.325'}
# {'Países': 'Vanuatu', 'Quantidade (Kg)': '-', 'Valor (US$)': '-'}
# {'Países': 'Venezuela', 'Quantidade (Kg)': '122.922', 'Valor (US$)': '199.418'}
# {'Países': 'Vietnã', 'Quantidade (Kg)': '16', 'Valor (US$)': '41'}
# {'Países': 'Total', 'Quantidade (Kg)': '5.324.465', 'Valor (US$)': '8.751.275'}
