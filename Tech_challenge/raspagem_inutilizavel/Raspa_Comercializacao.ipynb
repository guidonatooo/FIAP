# %%
import requests
from bs4 import BeautifulSoup

# Função que faz o scraping para um ano específico
def raspar_dados_ano(ano):
    url = f"http://vitibrasil.cnpuv.embrapa.br/index.php?opcao=opt_04&ano={ano}"
    resposta = requests.get(url)

    if resposta.status_code == 200:
        soup = BeautifulSoup(resposta.text, 'html.parser')

        # Encontra a tabela (pode ajustar se tiver mais de uma tabela na página)
        tabela = soup.find('table', {'class': 'tb_base tb_dados'})

        if tabela:
            linhas = tabela.find_all('tr')
            dados = []
            categoria_atual = None
            
            for linha in linhas:
                colunas = linha.find_all('td')
                
                if not colunas:
                    continue  # Pula linhas vazias
                
                primeira_coluna = colunas[0]
                
                if 'tb_item' in primeira_coluna.get('class', []):
                    categoria_atual = primeira_coluna.text.strip()
                    dados.append({
                        'Categoria': categoria_atual,
                        'Produto': '-',
                        'Quantidade': [col.text.strip() for col in colunas[1:]]
                    })
                elif 'tb_subitem' in primeira_coluna.get('class', []):
                    produto = primeira_coluna.text.strip()
                    dados.append({
                        'Categoria': categoria_atual,
                        'Produto': produto,
                        'Quantidade': [col.text.strip() for col in colunas[1:]]
                    })
            
            # Exibir os dados organizados
            for d in dados:
                print(f"{d['Categoria']} -> {d['Produto']} | {d['Quantidade']}")

            return dados
        else:
            print(f"Nenhuma tabela encontrada para o ano {ano}")
            return None
    else:
        print(f"Erro ao acessar o ano {ano}: {resposta.status_code}")
        return None

# Exemplo: pegar dados de 2023
dados = raspar_dados_ano(2023)

# Exibir resultado
for linha in dados:
    print(linha)
# Out:
# VINHO DE MESA -> - | ['187.016.848']
# VINHO DE MESA -> Tinto | ['165.097.539']
# VINHO DE MESA -> Rosado | ['2.520.748']
# VINHO DE MESA -> Branco | ['19.398.561']
# VINHO FINO DE MESA -> - | ['18.589.310']
# VINHO FINO DE MESA -> Tinto | ['12.450.606']
# VINHO FINO DE MESA -> Rosado | ['1.214.583']
# VINHO FINO DE MESA -> Branco | ['4.924.121']
# VINHO FRIZANTE -> - | ['2.843.600']
# VINHO ORGÂNICO -> - | ['9.123']
# VINHO ESPECIAL -> - | ['-']
# VINHO ESPECIAL -> Tinto | ['-']
# VINHO ESPECIAL -> Rosado | ['-']
# VINHO ESPECIAL -> Branco | ['-']
# ESPUMANTES -> - | ['29.381.635']
# ESPUMANTES -> Espumante  Moscatel | ['9.771.698']
# ESPUMANTES -> Espumante | ['19.609.379']
# ESPUMANTES -> Espumante Orgânico | ['558']
# SUCO DE UVAS -> - | ['166.708.720']
# SUCO DE UVAS -> Suco Natural Integral | ['129.419.407']
# SUCO DE UVAS -> Suco Adoçado | ['128.599']
# SUCO DE UVAS -> Suco Reprocessado/reconstituido | ['34.402.925']
# SUCO DE UVAS -> Suco Orgânico | ['932.154']
# SUCO DE UVAS -> Outros sucos de uvas | ['1.825.635']
# SUCO DE UVAS CONCENTRADO -> - | ['37.852.507']
# OUTROS PRODUTOS COMERCIALIZADOS -> - | ['29.889.342']
# OUTROS PRODUTOS COMERCIALIZADOS -> Outros vinhos (sem informação detalhada) | ['8.152']
# OUTROS PRODUTOS COMERCIALIZADOS -> Agrin (fermentado, acetico misto) | ['-']
# OUTROS PRODUTOS COMERCIALIZADOS -> Aguardente de vinho 50°gl | ['111']
# OUTROS PRODUTOS COMERCIALIZADOS -> Alcool vinico | ['-']
# OUTROS PRODUTOS COMERCIALIZADOS -> Bagaceira (graspa) | ['-']
# OUTROS PRODUTOS COMERCIALIZADOS -> Base champenoise champanha | ['66.290']
# OUTROS PRODUTOS COMERCIALIZADOS -> Base charmat champanha | ['184.040']
# OUTROS PRODUTOS COMERCIALIZADOS -> Base espumante moscatel | ['722.984']
# OUTROS PRODUTOS COMERCIALIZADOS -> Bebida de uva | ['16.780']
# OUTROS PRODUTOS COMERCIALIZADOS -> Borra líquida | ['72.600']
# OUTROS PRODUTOS COMERCIALIZADOS -> Borra seca | ['53.220']
# OUTROS PRODUTOS COMERCIALIZADOS -> Brandy (conhaque) | ['4.506']
# OUTROS PRODUTOS COMERCIALIZADOS -> Cooler | ['4.321.881']
# OUTROS PRODUTOS COMERCIALIZADOS -> Coquetel com vinho | ['397.156']
# OUTROS PRODUTOS COMERCIALIZADOS -> Destilado de vinho | ['245']
# OUTROS PRODUTOS COMERCIALIZADOS -> Filtrado doce | ['2.366.601']
# OUTROS PRODUTOS COMERCIALIZADOS -> Jeropiga | ['346']
# OUTROS PRODUTOS COMERCIALIZADOS -> Mistelas | ['1.668']
# OUTROS PRODUTOS COMERCIALIZADOS -> Mosto concentrado | ['-']
# OUTROS PRODUTOS COMERCIALIZADOS -> Mosto de uva | ['359.626']
# OUTROS PRODUTOS COMERCIALIZADOS -> Mosto sulfitado | ['-']
# OUTROS PRODUTOS COMERCIALIZADOS -> Nectar de uva | ['3.604.413']
# OUTROS PRODUTOS COMERCIALIZADOS -> Outros produtos | ['7.459.271']
# OUTROS PRODUTOS COMERCIALIZADOS -> Polpa de uva | ['1.331.651']
# OUTROS PRODUTOS COMERCIALIZADOS -> Preparado líquido para refresco | ['17.178']
# OUTROS PRODUTOS COMERCIALIZADOS -> Refrigerante +50% suco | ['501.876']
# OUTROS PRODUTOS COMERCIALIZADOS -> Sangria | ['84.157']
# OUTROS PRODUTOS COMERCIALIZADOS -> Vinagre balsamico | ['338.926']
# OUTROS PRODUTOS COMERCIALIZADOS -> Vinagre duplo | ['1.769.130']
# OUTROS PRODUTOS COMERCIALIZADOS -> Vinagre simples | ['5.047.280']
# OUTROS PRODUTOS COMERCIALIZADOS -> Vinho acetificado | ['194.020']
# OUTROS PRODUTOS COMERCIALIZADOS -> Vinho base para espumantes | ['-']
# OUTROS PRODUTOS COMERCIALIZADOS -> Vinho composto | ['981']
# OUTROS PRODUTOS COMERCIALIZADOS -> Vinho licoroso | ['421.974']
# OUTROS PRODUTOS COMERCIALIZADOS -> Vinho leve | ['132.064']
# OUTROS PRODUTOS COMERCIALIZADOS -> Vinho gaseificado | ['410.215']
# {'Categoria': 'VINHO DE MESA', 'Produto': '-', 'Quantidade': ['187.016.848']}
# {'Categoria': 'VINHO DE MESA', 'Produto': 'Tinto', 'Quantidade': ['165.097.539']}
# {'Categoria': 'VINHO DE MESA', 'Produto': 'Rosado', 'Quantidade': ['2.520.748']}
# {'Categoria': 'VINHO DE MESA', 'Produto': 'Branco', 'Quantidade': ['19.398.561']}
# {'Categoria': 'VINHO FINO DE MESA', 'Produto': '-', 'Quantidade': ['18.589.310']}
# {'Categoria': 'VINHO FINO DE MESA', 'Produto': 'Tinto', 'Quantidade': ['12.450.606']}
# {'Categoria': 'VINHO FINO DE MESA', 'Produto': 'Rosado', 'Quantidade': ['1.214.583']}
# {'Categoria': 'VINHO FINO DE MESA', 'Produto': 'Branco', 'Quantidade': ['4.924.121']}
# {'Categoria': 'VINHO FRIZANTE', 'Produto': '-', 'Quantidade': ['2.843.600']}
# {'Categoria': 'VINHO ORGÂNICO', 'Produto': '-', 'Quantidade': ['9.123']}
# {'Categoria': 'VINHO ESPECIAL', 'Produto': '-', 'Quantidade': ['-']}
# {'Categoria': 'VINHO ESPECIAL', 'Produto': 'Tinto', 'Quantidade': ['-']}
# {'Categoria': 'VINHO ESPECIAL', 'Produto': 'Rosado', 'Quantidade': ['-']}
# {'Categoria': 'VINHO ESPECIAL', 'Produto': 'Branco', 'Quantidade': ['-']}
# {'Categoria': 'ESPUMANTES', 'Produto': '-', 'Quantidade': ['29.381.635']}
# {'Categoria': 'ESPUMANTES', 'Produto': 'Espumante  Moscatel', 'Quantidade': ['9.771.698']}
# {'Categoria': 'ESPUMANTES', 'Produto': 'Espumante', 'Quantidade': ['19.609.379']}
# {'Categoria': 'ESPUMANTES', 'Produto': 'Espumante Orgânico', 'Quantidade': ['558']}
# {'Categoria': 'SUCO DE UVAS', 'Produto': '-', 'Quantidade': ['166.708.720']}
# {'Categoria': 'SUCO DE UVAS', 'Produto': 'Suco Natural Integral', 'Quantidade': ['129.419.407']}
# {'Categoria': 'SUCO DE UVAS', 'Produto': 'Suco Adoçado', 'Quantidade': ['128.599']}
# {'Categoria': 'SUCO DE UVAS', 'Produto': 'Suco Reprocessado/reconstituido', 'Quantidade': ['34.402.925']}
# {'Categoria': 'SUCO DE UVAS', 'Produto': 'Suco Orgânico', 'Quantidade': ['932.154']}
# {'Categoria': 'SUCO DE UVAS', 'Produto': 'Outros sucos de uvas', 'Quantidade': ['1.825.635']}
# {'Categoria': 'SUCO DE UVAS CONCENTRADO', 'Produto': '-', 'Quantidade': ['37.852.507']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': '-', 'Quantidade': ['29.889.342']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Outros vinhos (sem informação detalhada)', 'Quantidade': ['8.152']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Agrin (fermentado, acetico misto)', 'Quantidade': ['-']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Aguardente de vinho 50°gl', 'Quantidade': ['111']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Alcool vinico', 'Quantidade': ['-']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Bagaceira (graspa)', 'Quantidade': ['-']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Base champenoise champanha', 'Quantidade': ['66.290']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Base charmat champanha', 'Quantidade': ['184.040']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Base espumante moscatel', 'Quantidade': ['722.984']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Bebida de uva', 'Quantidade': ['16.780']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Borra líquida', 'Quantidade': ['72.600']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Borra seca', 'Quantidade': ['53.220']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Brandy (conhaque)', 'Quantidade': ['4.506']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Cooler', 'Quantidade': ['4.321.881']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Coquetel com vinho', 'Quantidade': ['397.156']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Destilado de vinho', 'Quantidade': ['245']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Filtrado doce', 'Quantidade': ['2.366.601']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Jeropiga', 'Quantidade': ['346']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Mistelas', 'Quantidade': ['1.668']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Mosto concentrado', 'Quantidade': ['-']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Mosto de uva', 'Quantidade': ['359.626']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Mosto sulfitado', 'Quantidade': ['-']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Nectar de uva', 'Quantidade': ['3.604.413']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Outros produtos', 'Quantidade': ['7.459.271']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Polpa de uva', 'Quantidade': ['1.331.651']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Preparado líquido para refresco', 'Quantidade': ['17.178']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Refrigerante +50% suco', 'Quantidade': ['501.876']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Sangria', 'Quantidade': ['84.157']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Vinagre balsamico', 'Quantidade': ['338.926']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Vinagre duplo', 'Quantidade': ['1.769.130']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Vinagre simples', 'Quantidade': ['5.047.280']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Vinho acetificado', 'Quantidade': ['194.020']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Vinho base para espumantes', 'Quantidade': ['-']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Vinho composto', 'Quantidade': ['981']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Vinho licoroso', 'Quantidade': ['421.974']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Vinho leve', 'Quantidade': ['132.064']}
# {'Categoria': 'OUTROS PRODUTOS COMERCIALIZADOS', 'Produto': 'Vinho gaseificado', 'Quantidade': ['410.215']}
